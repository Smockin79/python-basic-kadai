# %%
array = [
    "月曜日は晴れです",
    "火曜日は雨です",
    "水曜日は晴れです",
    "木曜日は晴れです",
    "金曜日は曇りです",
    "土曜日は曇りのち雨です",
    "日曜日は雷雨です"
]

print(array[2])

dictionary = {
    "mon": "晴れ",
    "tue": "雨",
    "wed": "晴れ",
    "thu": "晴れ",
    "fri": "曇り",
    "sat": "曇りのち雨",
    "sun": "雷雨"
}

print(dictionary["wed"])
# Out:
# 水曜日は晴れです
# 晴れ

# %%
array = ["月曜日は晴れ", "火曜日は曇り", "水曜日は雨"]

dictionary = {
    "月曜日": "晴れ",
    "火曜日": "曇り",
    "水曜日": "雨"
}

print(array[2])
print(dictionary["水曜日"])
# Out:
# 水曜日は雨
# 雨
